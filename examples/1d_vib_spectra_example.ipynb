# %% [markdown]
# ## Calculate Photoluminescence within strong el-ph limit.
# # It requires the values of ZPL, phonon frequencies of ground and excited states (which can be calculated from 1D configuration co-ordinate diagram) and the temperatures

# %%
from defectpl.vibspectra1d import VibrationalSpectra1D

# %%
ligo = VibrationalSpectra1D(2.6, 35.75, 41.56, 1.5476, 300, 1.2, 0.001, 1800)
# Out:
# Relaxation energy in ground state: 0.366042 eV
# Relaxation energy in excited state: 0.494686 eV

# %%
ligo.compute_lineshape()
# Out:
# This number should be close to 1.00, if that is not the case, increase NN1 and NN2: 1.000000

# %%
ligo.plot_lineshape(save_file="../../docs/plots/one_d_lineshape.svg", figsize=(4, 4))
# Out:
# Lineshape plot saved to ../../docs/plots/one_d_lineshape.svg
# C:\Users\shibu\local_code_library\high_throughput_framework\defectpl\defectpl\defectpl\vibspectra1d.py:187: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
ligo.plot_lineshape??
# Out:
# Signature: ligo.plot_lineshape(save_file=None, figsize=(6, 4))
# Docstring: <no docstring>
# Source:
#     def plot_lineshape(self, save_file=None, figsize=(6, 4)):
#         if not hasattr(self, "spectral_data"):
#             raise ValueError("Run compute_lineshape() before plotting.")
#         plt.figure(figsize=(6, 4))
#         #        plt.plot(self.spectral_data["energies"], self.spectral_data["dos"], label='DOS', linestyle='--', linewidth=2)
#         #        plt.plot(self.spectral_data["energies"], self.spectral_data["dosw3"], label='DOS * E³', linestyle='--', linewidth=2)
#         plt.plot(
#             self.spectral_data["energies"], self.spectral_data["dosw3"], linewidth=2
#         )
#         plt.xlabel("Energy (eV)")
#         plt.ylabel("Intensity (arb. units)")
#         plt.title("Vibrational Lineshape")
#         # plt.grid(True)
#         plt.legend()
#         plt.tight_layout()
#         if save_file:
#             plt.savefig(save_file, dpi=300)
# ...

# %%
ligo.save_results()

# %%
ligo.calculate_parameters()
# Out:
# Relaxation energy in ground state: 0.366042 eV
# Relaxation energy in excited state: 0.494686 eV

# %%
ligo.get_fwhm()
# Out:
# The full-width at half maximum (FWHM) is: 0.449 eV at 300 K.
# 0.44899999999999984

# %%
ligo.get_peak_position()
# Out:
# The peak position is: 2.183 eV at 300 K.
# (2.183, 2.0880050526893195)

# %%
# ligo.NN1 = 21
# ligo.NN2 = 53

# %%
ligo.compute_lineshape()
# Out:
# This number should be close to 1.00, if that is not the case, increase NN1 and NN2: 1.000000

# %%
ligo.plot_lineshape()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
no_01 = VibrationalSpectra1D(1.66, 39, 36, 2.09, 300, 0.4, 0.001, 1800)
# Out:
# Relaxation energy in ground state: 0.794480 eV
# Relaxation energy in excited state: 0.676954 eV

# %%
no_01.compute_lineshape()
# Out:
# This number should be close to 1.00, if that is not the case, increase NN1 and NN2: 1.000000

# %%
no_01.plot_lineshape()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
no_01.get_fwhm()
no_01.get_peak_position()
# Out:
# The full-width at half maximum (FWHM) is: 0.419 eV
# The peak position is: 1.086 eV
# (1.086, 2.2396262054120486)
